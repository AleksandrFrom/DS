# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook

# %%
df_144 = pd.read_excel('data/81-144.xlsx')
df_145 = pd.read_excel('data/81-145.xlsx')
df_146 = pd.read_excel('data/81-146.xlsx')
df_147 = pd.read_excel('data/81-147.xlsx')
df_151 = pd.read_excel('data/81-151.xlsx')
df_152 = pd.read_excel('data/81-152.xlsx')
df_153 = pd.read_excel('data/81-153.xlsx')
df_154 = pd.read_excel('data/81-154.xlsx')
df_155 = pd.read_excel('data/81-155.xlsx')
df_156 = pd.read_excel('data/81-156.xlsx')
df_157 = pd.read_excel('data/81-157.xlsx')
df_158 = pd.read_excel('data/81-158.xlsx')
df_163 = pd.read_excel('data/81-163.xlsx')
df_164 = pd.read_excel('data/81-164.xlsx')
df_167 = pd.read_excel('data/81-167.xlsx')
df_168 = pd.read_excel('data/81-168.xlsx')
df_169 = pd.read_excel('data/81-169.xlsx')
df_170 = pd.read_excel('data/81-170.xlsx')
df_172 = pd.read_excel('data/81-172.xlsx')
df_173 = pd.read_excel('data/81-173.xlsx')
df_174 = pd.read_excel('data/81-174.xlsx')
df_175 = pd.read_excel('data/81-175.xlsx')
df_177 = pd.read_excel('data/81-177.xlsx')
df_186 = pd.read_excel('data/81-186.xlsx')
df_188 = pd.read_excel('data/81-188.xlsx')
df_197 = pd.read_excel('data/81-197.xlsx')

# %%
df_144.head(3)
# Out:
#    Linera density  SA linear  Density yarn  Strength Gpa  Module Gpa  \
# 0             188  -1.052632         1.758          4.59         253
# 1             189  -0.526316         1.758          4.48         260
# 2             188  -1.052632         1.759          4.28         257
#
#    lengthening Mass size breaking the loop  Surface density of the fabric  \
# 0     1.814229         1                 -                          196.0
# 1     1.723077       1.1                 -                            NaN
# 2     1.665370         1                 -                            NaN
#
#    Prepreg surface density  ...  viscosity  Gelation time  Resin Tg  \
# 0                    319.4  ...     23.672           19.0     150.2
# 1                      NaN  ...        NaN            NaN       NaN
# 2                      NaN  ...        NaN            NaN       NaN
#
#    technology Thickness of the monolayer  density  Strength_plastik  \
# ...

# %%
df_144 = df_144.drop('SA linear', axis=1)
df_145 = df_145.drop('SA linear', axis=1)
df_146 = df_146.drop('SA linear', axis=1)
df_147 = df_147.drop('SA linear', axis=1)
df_151 = df_151.drop('SA linear', axis=1)
df_152 = df_152.drop('SA linear', axis=1)
df_153 = df_153.drop('SA linear', axis=1)
df_154 = df_154.drop('SA linear', axis=1)
df_155 = df_155.drop('SA linear', axis=1)
df_156 = df_156.drop('SA linear', axis=1)
df_157 = df_157.drop('SA linear', axis=1)
df_158 = df_158.drop('SA linear', axis=1)
df_163 = df_163.drop('SA linear', axis=1)
df_164 = df_164.drop('SA linear', axis=1)
df_167 = df_167.drop('SA linear', axis=1)
df_168 = df_168.drop('SA linear', axis=1)
df_169 = df_169.drop('SA linear', axis=1)
df_170 = df_170.drop('SA linear', axis=1)
df_172 = df_172.drop('SA linear', axis=1)
df_173 = df_173.drop('SA linear', axis=1)
df_174 = df_174.drop('SA linear', axis=1)
df_175 = df_175.drop('SA linear', axis=1)
df_177 = df_177.drop('SA linear', axis=1)
df_186 = df_186.drop('SA linear', axis=1)
df_188 = df_188.drop('SA linear', axis=1)
df_197 = df_197.drop('SA linear', axis=1)

# %%
df_144 = df_144.replace('-', np.nan)
df_145 = df_145.replace('-', np.nan)
df_146 = df_146.replace('-', np.nan)
df_147 = df_147.replace('-', np.nan)
df_151 = df_151.replace('-', np.nan)
df_152 = df_152.replace('-', np.nan)
df_153 = df_153.replace('-', np.nan)
df_154 = df_154.replace('-', np.nan)
df_155 = df_155.replace('-', np.nan)
df_156 = df_156.replace('-', np.nan)
df_157 = df_157.replace('-', np.nan)
df_158 = df_158.replace('-', np.nan)
df_163 = df_163.replace('-', np.nan)
df_164 = df_164.replace('-', np.nan)
df_167 = df_167.replace('-', np.nan)
df_168 = df_168.replace('-', np.nan)
df_169 = df_169.replace('-', np.nan)
df_170 = df_170.replace('-', np.nan)
df_172 = df_172.replace('-', np.nan)
df_173 = df_173.replace('-', np.nan)
df_174 = df_174.replace('-', np.nan)
df_175 = df_175.replace('-', np.nan)
df_177 = df_177.replace('-', np.nan)
df_186 = df_186.replace('-', np.nan)
df_188 = df_188.replace('-', np.nan)
df_197 = df_197.replace('-', np.nan)
# Out:
# /tmp/ipykernel_11699/3289886207.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_144 = df_144.replace('-', np.nan)
# /tmp/ipykernel_11699/3289886207.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_145 = df_145.replace('-', np.nan)
# ...

# %%
def replace_tech(df):
    if df['technology'][0] == 'v':
        df['technology'] = np.where(df['technology'].isnull(), 'v', 'v')
    else:
        df['technology'] = np.where(df['technology'].isnull(), 'a', 'a')

# %%
df_all = [df_144, df_145, df_146, df_147, df_151, df_152, df_153, df_154, df_155, df_156,
      df_157, df_158, df_163, df_164, df_167, df_168, df_169, df_170, df_172, df_173,
      df_174, df_175, df_177, df_186, df_188, df_197]

# %%
for df in df_all:
    replace_tech(df)

# %%
df_145.head()
# Out:
#    Linera density  Density yarn  Strength Gpa  Module Gpa  lengthening  \
# 0             188         1.752          4.29         254     1.688976
# 1             184         1.751          4.30         255     1.686275
# 2             179         1.750          4.62         268     1.723881
# 3             189         1.749          4.37         254     1.720472
# 4             189         1.749          4.26         255     1.670588
#
#    Mass size  breaking the loop  Surface density of the fabric  \
# 0        1.1               26.2                          197.5
# 1        1.2               24.7                            NaN
# 2        1.2               26.3                            NaN
# 3        1.1               25.6                            NaN
# 4        1.0               24.8                            NaN
#
#    Prepreg surface density  Resin content  viscosity  Gelation time  Resin Tg  \
# ...

# %%
#df_144['technology'] = np.where(df_144['technology'].isnull(), 'v', 'v')
#df_144

# %%
def replace_fillna(df):
    
    df['Mass size'] = df['Mass size'].fillna(df['Mass size'].mean())
    df['breaking the loop'] = df['breaking the loop'].fillna(df['breaking the loop'].median())
    df['Surface density of the fabric'] = df['Surface density of the fabric'].fillna(df['Surface density of the fabric'].mean())
    df['Prepreg surface density'] = df['Prepreg surface density'].fillna(df['Prepreg surface density'].mean())
    df['Resin content'] = df['Resin content'].fillna(df['Resin content'].mean())
    df['viscosity'] = df['viscosity'].fillna(df['viscosity'].mean())
    df['Gelation time'] = df['Gelation time'].fillna(df['Gelation time'].mean())
    df['Resin Tg'] = df['Resin Tg'].fillna(df['Resin Tg'].mean())
    df['Thickness of the monolayer'] = df['Thickness of the monolayer'].fillna(df['Thickness of the monolayer'].mean())
    df['density'] = df['density'].fillna(df['density'].mean())
    df['Strength_plastik'] = df['Strength_plastik'].fillna(df['Strength_plastik'].median())
    df['Module_plastik '] = df['Module_plastik '].fillna(df['Module_plastik '].median())
    df['LSS'] = df['LSS'].fillna(df['LSS'].mean())
    df['Plastik_Tg'] = df['Plastik_Tg'].fillna(df['Plastik_Tg'].mean())
    
    return df

# %%
for df in df_all:
    replace_fillna(df)

# %%
df_144.head()
# Out:
#    Linera density  Density yarn  Strength Gpa  Module Gpa  lengthening  \
# 0             188         1.758          4.59         253     1.814229
# 1             189         1.758          4.48         260     1.723077
# 2             188         1.759          4.28         257     1.665370
# 3             187         1.758          4.77         256     1.863281
# 4             190         1.757          4.56         255     1.788235
#
#    Mass size  breaking the loop  Surface density of the fabric  \
# 0        1.0               24.3                          196.0
# 1        1.1               24.3                          196.0
# 2        1.0               24.3                          196.0
# 3        1.0               24.3                          196.0
# 4        0.9               24.3                          196.0
#
#    Prepreg surface density  Resin content  viscosity  Gelation time  Resin Tg  \
# ...

# %%
df_151.head()
# Out:
#    Linera density  Density yarn  Strength Gpa  Module Gpa  lengthening  \
# 0             188         1.760          4.65         263     1.768061
# 1             186         1.755          4.57         257     1.778210
# 2             185         1.754          4.37         257     1.700389
# 3             186         1.758          4.51         246     1.833333
# 4             187         1.755          4.27         255     1.674510
#
#    Mass size  breaking the loop  Surface density of the fabric  \
# 0        0.9               25.5                          198.0
# 1        1.0               25.5                          198.0
# 2        1.0               25.5                          198.0
# 3        0.8               25.5                          198.0
# 4        0.9               25.5                          198.0
#
#    Prepreg surface density  Resin content  viscosity  Gelation time  Resin Tg  \
# ...

# %%
df_all_concat = pd.concat([df_144, df_145, df_146, df_147, df_151, df_152, df_153, df_154, df_155, df_156,
      df_157, df_158, df_163, df_164, df_167, df_168, df_169, df_170, df_172, df_173,
      df_174, df_175, df_177, df_186, df_188, df_197])

df_all_concat
# Out:
#      Linera density  Density yarn  Strength Gpa  Module Gpa  lengthening  \
# 0             188.0         1.758         4.590       253.0     1.814229
# 1             189.0         1.758         4.480       260.0     1.723077
# 2             188.0         1.759         4.280       257.0     1.665370
# 3             187.0         1.758         4.770       256.0     1.863281
# 4             190.0         1.757         4.560       255.0     1.788235
# ..              ...           ...           ...         ...          ...
# 408           189.0         1.783         4.640       271.0     1.712177
# 409           189.0         1.780         4.500       284.0     1.584507
# 410           190.0         1.783         4.838       270.0     1.791852
# 411           191.0         1.779         4.820       271.0     1.778598
# 412           189.0         1.782         4.630       270.0     1.714815
#
#      Mass size  breaking the loop  Surface density of the fabric  \
# ...

# %%
df_all_concat.to_csv('data/dataset.csv', index=False, encoding='utf-8')

# %%
df_all_concat_2 = pd.read_csv('data/dataset.csv')

df_all_concat_2
# Out:
#        Linera density  Density yarn  Strength Gpa  Module Gpa  lengthening  \
# 0               188.0         1.758         4.590       253.0     1.814229
# 1               189.0         1.758         4.480       260.0     1.723077
# 2               188.0         1.759         4.280       257.0     1.665370
# 3               187.0         1.758         4.770       256.0     1.863281
# 4               190.0         1.757         4.560       255.0     1.788235
# ...               ...           ...           ...         ...          ...
# 11123           189.0         1.783         4.640       271.0     1.712177
# 11124           189.0         1.780         4.500       284.0     1.584507
# 11125           190.0         1.783         4.838       270.0     1.791852
# 11126           191.0         1.779         4.820       271.0     1.778598
# 11127           189.0         1.782         4.630       270.0     1.714815
#
# ...
