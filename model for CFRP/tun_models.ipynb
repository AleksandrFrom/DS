# %%
import pandas as pd
import numpy as np

# инструменты для построения модели:
from sklearn.linear_model import LinearRegression # инструмент для создания и обучения модели
from sklearn.ensemble import RandomForestRegressor # инструмент для создания и обучения модели

import pickle

# %%
with open('autoclave_model_rf_density.pkl', 'rb') as file:
    density_model = pickle.load(file)

with open('autoclave_model_rf_thikness.pkl', 'rb') as file:
    thikness_model = pickle.load(file)

with open('autoclave_model_rf_strength.pkl', 'rb') as file:
    strength_model = pickle.load(file)

with open('autoclave_model_rf_module.pkl', 'rb') as file:
    module_model = pickle.load(file)

with open('autoclave_model_rf_lss.pkl', 'rb') as file:
    lss_model = pickle.load(file)

with open('autoclave_model_rf_Tg.pkl', 'rb') as file:
    tg_model = pickle.load(file)

# %%
x1 = np.array([[185.62, 1.769, 4.56, 261, 1.75, 1.07, 26.8, 200, 325.7, 38.57, 32.35, 12, 152]])
x2 = np.array([[185.62, 1.769, 4.56, 261, 1.75, 1.07, 26.8, 200, 330.5, 39.43, 30.85, 10.82, 150.36]])

# %%
def predict_cfrp(x):
    dens = density_model.predict(x)
    thik = thikness_model.predict(x)
    strenght = strength_model.predict(x)
    module = module_model.predict(x)
    lss = lss_model.predict(x)
    tg = tg_model.predict(x)
    print(f'Плотность= {dens}, \nТолщина монослоя= {thik}, \nПрочность= {strenght}, \nМодуль={module}, \nСдвиг={lss}, \nTg={tg}')

# %%
predict_cfrp(x2)
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 600 out of 600 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# Плотность= [1.54363124],
# Толщина монослоя= [0.20942216],
# Прочность= [965.28263332],
# Модуль=[67.2029733],
# Сдвиг=[80.74995228],
# Tg=[160.31351711]
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.1s finished
