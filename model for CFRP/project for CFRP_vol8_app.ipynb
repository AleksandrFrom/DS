# %%
import tkinter as tk
from tkinter import ttk

import numpy as np
import predict_helper_avt as pred

# %%
window = tk.Tk()
window.title('My App')
# Out:
# ''

# %%
x = np.array([[190, 1.779, 4.6, 265, 1.7, 1.3, 20, 210, 333, 37.40, 32.33, 12.8, 149.0]])

# %%
def form_submit():
    print('GOOD')

# %%
def components(**kwargs):
    x = []
    x.append(float(l_linear_density_f.get()))
    x.append(float(l_density_yarn_f.get()))
    x.append(float(l_strenght_yarn_f.get()))
    x.append(float(l_module_yarn_f.get()))
    x.append(float(l_lengthening_f.get()))
    x.append(float(l_mass_size_f.get()))
    x.append(float(l_loop_f.get()))
    x.append(float(l_loop_f.get()))
    x.append(float(l_density_fabric_f.get()))
    x.append(float(l_prepreg_density_f.get()))
    x.append(float(l_resin_content_f.get()))
    x.append(float(l_viscosity_f.get()))
    x.append(float(l_gel_time_f.get()))
    x.append(float(l_resin_tg_f.get()))
    x = np.array([x])
    return print(x)

# %%
frame_add_from = tk.Frame(window, bg='green')
frame_statistic = tk.Frame(window, bg='yellow')
frame_list = tk.Frame(window, bg='blue')

frame_add_from.grid(column=0, row=0, sticky='ns')
frame_statistic.grid(column=1, row=0)
frame_list.grid(column=0, row=1, columnspan=2, sticky='we')

items = ['autoclave', 'vacuum']


l_technology = ttk.Label(frame_add_from, text='Enter technology')
l_technology_f = ttk.Combobox(frame_add_from, values = items)
l_linear_density = ttk.Label(frame_add_from, text='Enter linear_density')
l_linear_density_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_density_yarn = ttk.Label(frame_add_from, text='Enter density_yarn')
l_density_yarn_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_strenght_yarn = ttk.Label(frame_add_from, text='Enter strenght_yarn')
l_strenght_yarn_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_module_yarn = ttk.Label(frame_add_from, text='Enter module_yarn')
l_module_yarn_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_lengthening = ttk.Label(frame_add_from, text='Enter lengthening')
l_lengthening_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_mass_size = ttk.Label(frame_add_from, text='Enter mass_size')
l_mass_size_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_loop = ttk.Label(frame_add_from, text='Enter loop')
l_loop_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_density_fabric = ttk.Label(frame_add_from, text='Enter density_fabric')
l_density_fabric_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_prepreg_density = ttk.Label(frame_add_from, text='Enter prepreg_density')
l_prepreg_density_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_resin_content = ttk.Label(frame_add_from, text='Enter resin_content')
l_resin_content_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_viscosity = ttk.Label(frame_add_from, text='Enter viscosity')
l_viscosity_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_gel_time = ttk.Label(frame_add_from, text='Enter gel_time')
l_gel_time_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
l_resin_tg = ttk.Label(frame_add_from, text='Enter resin_tg')
l_resin_tg_f = ttk.Entry(frame_add_from, justify=tk.RIGHT)
btn_submit = ttk.Button(frame_add_from, command=components)


l_technology.grid(row=0, column=0, sticky='w', padx=2, pady=2)
l_technology_f.grid(row=0, column=1, sticky='e', padx=2, pady=2)
l_linear_density.grid(row=1, column=0, sticky='w', padx=2, pady=2)
l_linear_density_f.grid(row=1, column=1, sticky='e', padx=2, pady=2)
l_density_yarn.grid(row=2, column=0, sticky='w', padx=2, pady=2)
l_density_yarn_f.grid(row=2, column=1, sticky='e', padx=2, pady=2)
l_strenght_yarn.grid(row=3, column=0, sticky='w', padx=2, pady=2)
l_strenght_yarn_f.grid(row=3, column=1, sticky='e', padx=2, pady=2)
l_module_yarn.grid(row=4, column=0, sticky='w', padx=2, pady=2)
l_module_yarn_f.grid(row=4, column=1, sticky='e', padx=2, pady=2)
l_lengthening.grid(row=5, column=0, sticky='w', padx=2, pady=2)
l_lengthening_f.grid(row=5, column=1, sticky='e', padx=2, pady=2)
l_mass_size.grid(row=6, column=0, sticky='w', padx=2, pady=2)
l_mass_size_f.grid(row=6, column=1, sticky='e', padx=2, pady=2)
l_loop.grid(row=7, column=0, sticky='w', padx=2, pady=2)
l_loop_f.grid(row=7, column=1, sticky='e', padx=2, pady=2)
l_density_fabric.grid(row=8, column=0, sticky='w', padx=2, pady=2)
l_density_fabric_f.grid(row=8, column=1, sticky='e', padx=2, pady=2)
l_prepreg_density.grid(row=9, column=0, sticky='w', padx=2, pady=2)
l_prepreg_density_f.grid(row=9, column=1, sticky='e', padx=2, pady=2)
l_resin_content.grid(row=10, column=0, sticky='w', padx=2, pady=2)
l_resin_content_f.grid(row=10, column=1, sticky='e', padx=2, pady=2)
l_viscosity.grid(row=11, column=0, sticky='w', padx=2, pady=2)
l_viscosity_f.grid(row=11, column=1, sticky='e', padx=2, pady=2)
l_gel_time.grid(row=12, column=0, sticky='w', padx=2, pady=2)
l_gel_time_f.grid(row=12, column=1, sticky='e', padx=2, pady=2)
l_resin_tg.grid(row=13, column=0, sticky='w', padx=2, pady=2)
l_resin_tg_f.grid(row=13, column=1, sticky='e', padx=2, pady=2)
btn_submit.grid(row=14, column=0, columnspan=2, sticky='n', padx=5, pady=5)

# %%
l_thiknes_monolayer_text = tk.Label(frame_statistic, text='Толщина монослоя, мм', font='Arial 12 bold')
l_thiknes_monolayer_value = tk.Label(frame_statistic, text = pred.thikness_model.predict(x), font='Arial 12 bold')
l_density_pcm_text = tk.Label(frame_statistic, text='Плотность углепластика, г/см3', font='Arial 12 bold')
l_density_pcm_value = tk.Label(frame_statistic, text = pred.density_model.predict(x), font='Arial 12 bold')
l_strenght_pcm_tetx = tk.Label(frame_statistic, text='Прочность при растяжении, МПа', font='Arial 12 bold')
l_strenght_pcm_value = tk.Label(frame_statistic, text = pred.strength_model.predict(x), font='Arial 12 bold')
l_module_pcm_text = tk.Label(frame_statistic, text='Модуль упругости при растяжении, ГПа', font='Arial 12 bold')
l_module_pcm_value = tk.Label(frame_statistic, text = pred.module_model.predict(x), font='Arial 12 bold')
l_lss_pcm_tetx = tk.Label(frame_statistic, text='Прочность при межслоевом сдвиге, МПа', font='Arial 12 bold')
l_lss_pcm_value = tk.Label(frame_statistic, text = pred.lss_model.predict(x), font='Arial 12 bold')
l_tg_pcm_tetx = tk.Label(frame_statistic, text='Температура стеклования, оС', font='Arial 12 bold')
l_tg_pcm_value = tk.Label(frame_statistic, text = pred.tg_model.predict(x), font='Arial 12 bold')

l_thiknes_monolayer_text.grid(row='0', column='0', sticky='w', padx=10, pady=10)
l_thiknes_monolayer_value.grid(row='0', column='1', sticky='e', padx=10, pady=10)
l_density_pcm_text.grid(row='1', column='0', sticky='w', padx=10, pady=10)
l_density_pcm_value.grid(row='1', column='1', sticky='e', padx=10, pady=10)
l_strenght_pcm_tetx.grid(row='2', column='0', sticky='w', padx=10, pady=10)
l_strenght_pcm_value.grid(row='2', column='1', sticky='e', padx=10, pady=10)
l_module_pcm_text.grid(row='3', column='0', sticky='w', padx=10, pady=10)
l_module_pcm_value.grid(row='3', column='1', sticky='e', padx=10, pady=10)
l_lss_pcm_tetx.grid(row='4', column='0', sticky='w', padx=10, pady=10)
l_lss_pcm_value.grid(row='4', column='1', sticky='e', padx=10, pady=10)
l_tg_pcm_tetx.grid(row='5', column='0', sticky='w', padx=10, pady=10)
l_tg_pcm_value.grid(row='5', column='1', sticky='e', padx=10, pady=10)

l_temp_frame_add_form = tk.Label(frame_add_from, text='frame_add_form')
l_temp_frame_list = tk.Label(frame_list, text='frame_list')
#l_temp_frame_add_form.pack(expand=True, padx=40, pady=40)
l_temp_frame_list.pack(expand=True, padx=40, pady=40)
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# ...

# %%
list = [(1, 'Толщина монослоя', 'мм', pred.thikness_model.predict(x)),
        (2, 'Плотность углепластика', 'г/см3', pred.density_model.predict(x)),
        (3, 'Прочность при растяжении', 'МПа', pred.strength_model.predict(x)),
        (4, 'Модуль упругости при растяжении', 'ГПа', pred.module_model.predict(x)),
        (5, 'Прочность при межслоевом сдвиге', 'МПа', pred.lss_model.predict(x)),
        (6, 'Температура стеклования', 'оС', pred.tg_model.predict(x))]
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.1s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# ...

# %%
heads = ['№', 'Характеристика', 'ед. изм', 'Величина']
table = ttk.Treeview(frame_list, show='headings')
table['columns'] = heads

for header in heads:
    table.heading(header, text=header, anchor='center')
    table.column(header, anchor='center')

for row in list:
    table.insert('', tk.END, values=row)


scroll_plane = ttk.Scrollbar(frame_list, command=table.yview)
scroll_plane.pack(side=tk.RIGHT, fill=tk.Y)

table.pack(expand=tk.YES, fill=tk.BOTH)


window.mainloop()
# Out:
# [[  1.    2.    3.    4.    5.    6.    7.    7.    5.    5.3 125.1 111.
#    10.    1. ]]
