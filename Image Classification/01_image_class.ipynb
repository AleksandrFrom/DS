# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_image/sharapova1.jpg')
img
# Out:
# [ WARN:0@385.419] global loadsave.cpp:268 findDecoder imread_('./test_image/sharapova1.jpg'): can't open/read file: check file path/integrity
