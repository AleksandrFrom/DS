# %% [markdown]
# # Fraud Detection Using Machine Learning – Full Python Data Science Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid')

# %%
df = pd.read_csv('data/AIML Dataset.csv')

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %% [markdown]
# # EDA

# %%
df.info() #оценка датасета
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df['isFraud'].value_counts() #оценка распределния показателей
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df['isFlaggedFraud'].value_counts() #оценка распределния показателей
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum().sum() #поиск пропусков
# Out:
# np.int64(0)

# %%
#оценка в процентах 
round((df['isFraud'].value_counts()[1] / df.shape[0]) * 100, 2)
# Out:
# np.float64(0.13)

# %% [markdown]
# # Визуализация зависимостей

# %%
df['type'].value_counts().plot(kind='bar', title='Тип транзакций',
            color='skyblue')
plt.xlabel('Тип транзакций')
plt.ylabel('Количество')
plt.show()

# %%
fraud_type = df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
fraud_type.plot(kind='bar', title='Мошенничество', color='salmon')
plt.ylabel('Уровень мошенничества')
plt.show()

# %%
df['amount'].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df['amount']), bins=100, kde=True, color='green')
plt.title('Распределение сумм транзацкий (log масштаб)')
plt.xlabel('Log(amount +1)')
plt.show()

# %%
#оценка количества мошенничества по суммам
sns.boxplot(data=df[df['amount'] < 50000], x = 'isFraud', y='amount')
plt.title('сумма vs фрод (отфильтрованный ниже 50К)')
plt.show()

# %%
df.columns
# Out:
# Index(['type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balanceDiffOrig', 'balanceDiffDest'],
#       dtype='object')

# %%
df['balanceDiffOrig'] = df['oldbalanceOrg'] - df['newbalanceOrig']
df['balanceDiffDest'] = df['newbalanceDest'] - df['oldbalanceDest']

# %%
(df['balanceDiffOrig'] < 0).sum()
# Out:
# np.int64(1399253)

# %%
(df['balanceDiffDest'] < 0).sum()
# Out:
# np.int64(1238864)

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDest
# 0          9839.64              0.0
# 1          1864.28              0.0

# %%
frauds_per_step = df[df['isFraud'] == 1]['step'].value_counts().sort_index()
plt.plot(frauds_per_step.index, frauds_per_step.values, label = 'frauds per step')
plt.xlabel('Step (Time)')
plt.ylabel('Number over time')
plt.grid(True)
plt.show()

# %%
#удаление ненужной колонки
df.drop(columns='step', inplace=True)

# %%
df.head(2)
# Out:
#       type   amount     nameOrig  oldbalanceOrg  newbalanceOrig     nameDest  \
# 0  PAYMENT  9839.64  C1231006815       170136.0       160296.36  M1979787155
# 1  PAYMENT  1864.28  C1666544295        21249.0        19384.72  M2044282225
#
#    oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  balanceDiffOrig  \
# 0             0.0             0.0        0               0          9839.64
# 1             0.0             0.0        0               0          1864.28
#
#    balanceDiffDest
# 0              0.0
# 1              0.0

# %%
# отправители с наибольишм количеством транзакций
top_senders = df['nameOrig'].value_counts().head(10)

top_senders
# Out:
# nameOrig
# C1530544995    3
# C545315117     3
# C724452879     3
# C1784010646    3
# C1677795071    3
# C1462946854    3
# C1065307291    3
# C1999539787    3
# C2098525306    3
# C400299098     3
# Name: count, dtype: int64

# %%
top_resivers = df['nameDest'].value_counts().head(10)

top_resivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C1789550256     99
# C451111351      99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
fraud_users = df[df['isFraud'] == 1]['nameOrig'].value_counts().head(10)

# %%
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_types = df[df['type'].isin(['TRANSFER', 'CASH_OUT'])]

# %%
fraud_types['type'].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_types, x='type', hue='isFraud')
plt.title('Fraud distribution in Transfer & Cach_out')
# Out:
# Text(0.5, 1.0, 'Fraud distribution in Transfer & Cach_out')

# %%
df.columns
# Out:
# Index(['type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balanceDiffOrig', 'balanceDiffDest'],
#       dtype='object')

# %%
#фильтрование числовых данных для корреляционной матрицы

corr = df[['amount', 'oldbalanceOrg', 'newbalanceOrig', 'oldbalanceDest', 'newbalanceDest', 'isFraud']].corr()

corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr, annot=True, cmap = 'coolwarm', fmt='.2f')
plt.title('Correlation matrix')
# Out:
# Text(0.5, 1.0, 'Correlation matrix')

# %%
#клиенты у которых после трансфера юаланс = 0

zero_after_transfer = df[
    (df['oldbalanceOrg'] > 0) &
    (df['newbalanceOrig'] == 0) &
    (df['type'].isin(['TRANSFER', 'CASH_OUT']))
]

zero_after_transfer
# Out:
#              type      amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2        TRANSFER      181.00  C1305486145         181.00             0.0
# 3        CASH_OUT      181.00   C840083671         181.00             0.0
# 15       CASH_OUT   229133.94   C905080434       15325.00             0.0
# 19       TRANSFER   215310.30  C1670993182         705.00             0.0
# 24       TRANSFER   311685.89  C1984094095       10835.00             0.0
# ...           ...         ...          ...            ...             ...
# 6362615  CASH_OUT   339682.13   C786484425      339682.13             0.0
# 6362616  TRANSFER  6311409.28  C1529008245     6311409.28             0.0
# 6362617  CASH_OUT  6311409.28  C1162922333     6311409.28             0.0
# 6362618  TRANSFER   850002.52  C1685995037      850002.52             0.0
# 6362619  CASH_OUT   850002.52  C1280323807      850002.52             0.0
#
#             nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# ...

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
df['isFraud'].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64
