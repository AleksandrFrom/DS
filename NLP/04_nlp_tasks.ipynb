# %% [markdown]
# # 4. NLP Tasks: NLP Tutorial For Beginners In Python - S1 E5

# %% [markdown]
# 1. Text classification
#
# 2. Text similarity (сходство текста)
#
# 3. Information Extraction
#
# 4. Information Retrieval (поиск информации)
#
# 5. Mashine Translation
#
# 6. Text Summarization
