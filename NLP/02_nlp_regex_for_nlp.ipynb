# %% [markdown]
# # 03. Regex For NLP: NLP Tutorial For Beginners In Python - S1 E3

# %%
import re

# %%
chat1 = 'codebasics: you ask lot of questions 😠  1235678912, abc@xyz.com'
chat2 = 'codebasics: here it is: (123)-567-8912, abX_82@xyz.com'
chat3 = 'codebasics: yes, phone: 1235678912 email: abc@xyz.com'

# %%
pattern1 = '\d{10}'

matches = re.findall(pattern1, chat1)
matches
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_3444/2173484340.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern1 = '\d{10}'
# ['1235678912']

# %%
pattern2 = '\(\d{3}\)-\d{3}-\d{4}'

matches = re.findall(pattern2, chat2)
matches
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipykernel_3444/2998912553.py:1: SyntaxWarning: invalid escape sequence '\('
#   pattern2 = '\(\d{3}\)-\d{3}-\d{4}'
# ['(123)-567-8912']

# %%
pattern3 = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'

matches = re.findall(pattern3, chat1)
matches
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_3444/3162638410.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern3 = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'
# ['1235678912']

# %%
pattern4 = '[a-z0-9A-Z_]*@[a-z0-9A-Z_]*\.[a-zA-Z]*'

matches = re.findall(pattern4, chat2)
matches
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_3444/1700474416.py:1: SyntaxWarning: invalid escape sequence '\.'
#   pattern4 = '[a-z0-9A-Z_]*@[a-z0-9A-Z_]*\.[a-zA-Z]*'
# ['abX_82@xyz.com']
