# %% [markdown]
# # 01. Introduction | NLP Tutorial For Beginners In Python - Season 1 Episode 1

# %% [markdown]
# # 02. Why NLP is booming right now? | NLP Tutorial For Beginners In Python - S1 E2

# %%
import numpy as np
import pandas as pd
