# %% [markdown]
# # 05. NLP Pipeline: NLP Tutorial For Beginners In Python - S1 E6

# %% [markdown]
# 1. Data Acqusition - получение данных для последующей их обработки
#
# 2. Text Extraction and Cleanup
#
# 3. Pre-processing:  a) Sentence Tokenization -> b) Word Tokenization -> c) Stemming, Lemmatization (приведение к исходному слову)
#
# 4. Feature Engineering
#
# 5. Model Building
#
# 6. Evaluation
#
# 7. Deployment
#
# 8. Monitor and Update
