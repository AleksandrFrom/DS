# %% [markdown]
# # 08. Language Processing Pipeline in Spacy: NLP Tutorial For Beginners - S1 E9

# %%
import spacy

# %%
nlp = spacy.blank('en')

doc = nlp('Captain america ate 100$ of samosa. Then he said I can do this all day')

for token in doc:
    print(token)
# Out:
# Captain
# america
# ate
# 100
# $
# of
# samosa
# .
# Then
# he
# said
# I
# can
# do
# this
# all
# day

# %%
nlp.pipe_names
# Out:
# []

# %%
nlp = spacy.load('en_core_web_sm')

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x787e0695e630>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x787e0695e3f0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x787e06becf90>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x787e06993a50>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x787e069a3350>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x787e06bed000>)]

# %%
doc = nlp('Captain america ate 100$ of samosa. Then he said I can do this all day')

for token in doc:
    print(token, " | ", token.pos_, " | ", token.lemma_)
# Out:
# Captain  |  PROPN  |  Captain
# america  |  PROPN  |  america
# ate  |  VERB  |  eat
# 100  |  NUM  |  100
# $  |  NUM  |  $
# of  |  ADP  |  of
# samosa  |  PROPN  |  samosa
# .  |  PUNCT  |  .
# Then  |  ADV  |  then
# he  |  PRON  |  he
# said  |  VERB  |  say
# I  |  PRON  |  I
# can  |  AUX  |  can
# do  |  VERB  |  do
# this  |  PRON  |  this
# all  |  DET  |  all
# day  |  NOUN  |  day

# %%
doc = nlp('Tesla Inc is going to acquire twitter for $45 billion')

for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit

# %%
nlp = spacy.blank('en')

doc = nlp('Tesla Inc va racheter Twitter pour $45 milliards de dollars')

for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))

# %%
source_nlp = spacy.load('en_core_web_sm')

nlp = spacy.blank('en')
nlp.add_pipe('ner', source=source_nlp)
nlp.pipe_names
# Out:
# ['ner']

# %%
doc = nlp('Tesla Inc va racheter Twitter pour $45 milliards de dollars')

for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc va  |  ORG  |  Companies, agencies, institutions, etc.
# Twitter  |  PERSON  |  People, including fictional
# $45 milliards de dollars  |  MONEY  |  Monetary values, including unit

# %%
doc = nlp('Tesla Inc is going to acquire twitter for $45 billion')

for ent in doc.ents:
    print(ent.text, " | ", ent.label_, " | ", spacy.explain(ent.label_))
# Out:
# Tesla Inc  |  ORG  |  Companies, agencies, institutions, etc.
# $45 billion  |  MONEY  |  Monetary values, including unit
